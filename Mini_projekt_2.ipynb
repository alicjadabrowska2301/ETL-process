# %% [markdown]
# # Proces ETL dla danych Airbnb
# 1. Ekstrakcja danych, w tym określenie trybu dostępu do danych, identyfikacja anomalii, identyfikacja i obsługa zmian.
# 2.	Transformacja danych, w tym, czyszczenie anomalii, uzgadnianie oraz standaryzacja danych,

# %%
import pandas as pd

# %% [markdown]
# Wszystkie wykorzystane w ramach realizacji projektu dane zostały pobrane w postaci skompresowanych plików CSV ze strony interentowej http://insideairbnb.com/get-the-data

# %% [markdown]
# ### Wstępne wczytanie danych źródłowych w celu ich dalszego podziału na wymiary

# %% [markdown]
# Określenie trybu dostępu do danych:
#
# Pobrane ze strony dane mają postać plików CSV skompresowanych do pliku o rozszerzeniu .gz. Dla wymiaru listing, location, location_details oraz host jest to plik **listings.csv.gz.**
# Tryb dostępu: Otwieranie i odczytywanie pliku CSV przy użyciu biblioteki pandas metodą read_csv, z dodatkowym argumentem dekompresji jako gzip

# %%
#wczytanie danych
df = pd.read_csv('listings.csv.gz', compression='gzip', dtype='object', usecols=['id','listing_url', 'name', 'description','host_id','host_url', 'host_name',
                                                                                  'host_since', 'host_location', 'host_response_time', 'host_is_superhost', 
                                                                                  'host_total_listings_count', 'host_identity_verified','room_type', 'accommodates',
                                                                                  'bedrooms','beds','amenities', 'price', 'minimum_nights','maximum_nights',
                                                                                  'number_of_reviews', 'review_scores_rating', 'review_scores_accuracy',
                                                                                  'review_scores_cleanliness', 'review_scores_checkin', 'review_scores_communication',
                                                                                  'review_scores_location', 'review_scores_value', 'neighbourhood_cleansed',
                                                                                  'neighbourhood_group_cleansed', 'longitude', 'latitude'])

df.head(3)
# Out:
#                    id                                      listing_url  \
# 0  801749842377802394  https://www.airbnb.com/rooms/801749842377802394
# 1  765948794133787266  https://www.airbnb.com/rooms/765948794133787266
# 2  636274456676328779  https://www.airbnb.com/rooms/636274456676328779
#
#                     name                                        description  \
# 0  A home away from home  The whole group will be comfortable in this sp...
# 1        Brooklyn Refuge    Take a break and unwind at this peaceful oasis.
# 2          Villa Masino.  Close to beach   Peaceful walk to park & beach...
#
#      host_id                                     host_url host_name  \
# 0  495455523  https://www.airbnb.com/users/show/495455523   Michael
# 1  488760226  https://www.airbnb.com/users/show/488760226      Eric
# 2  461263600  https://www.airbnb.com/users/show/461263600   Tommaso
#
#    host_since host_location host_response_time  ... minimum_nights  \
# 0  2023-01-10           NaN                NaN  ...              2
# 1  2022-11-22           NaN     within an hour  ...              2
# 2  2022-05-27           NaN                NaN  ...              1
#
#   maximum_nights number_of_reviews review_scores_rating  \
# 0             30                 0                  NaN
# 1           1125                13                 4.85
# 2            365                 0                  NaN
#
#   review_scores_accuracy review_scores_cleanliness review_scores_checkin  \
# 0                    NaN                       NaN                   NaN
# 1                   4.77                      4.77                  4.85
# 2                    NaN                       NaN                   NaN
#
#   review_scores_communication review_scores_location review_scores_value
# 0                         NaN                    NaN                 NaN
# 1                        4.92                   4.85                4.92
# 2                         NaN                    NaN                 NaN
#
# [3 rows x 33 columns]

# %% [markdown]
# Tworzymy dodatkowe kolumny umożliwiające łączenie między wymiarami - klucze obce

# %%
#tworzymy nowe kolumny - klucze obce do wymiarow location, neighbourhood
df['coordinates'] = df['latitude'].astype(str) + ',' + df['longitude'].astype(str)
df['location_id'] = df['coordinates'].astype('category').cat.codes
#usuwamy kolumny z wspolrzednymi
df = df.drop(['coordinates'], axis=1)

df['neighbourhood_id'] = df['neighbourhood_cleansed'].astype('category').cat.codes

df.head(3)
# Out:
#                    id                                      listing_url  \
# 0  801749842377802394  https://www.airbnb.com/rooms/801749842377802394
# 1  765948794133787266  https://www.airbnb.com/rooms/765948794133787266
# 2  636274456676328779  https://www.airbnb.com/rooms/636274456676328779
#
#                     name                                        description  \
# 0  A home away from home  The whole group will be comfortable in this sp...
# 1        Brooklyn Refuge    Take a break and unwind at this peaceful oasis.
# 2          Villa Masino.  Close to beach   Peaceful walk to park & beach...
#
#      host_id                                     host_url host_name  \
# 0  495455523  https://www.airbnb.com/users/show/495455523   Michael
# 1  488760226  https://www.airbnb.com/users/show/488760226      Eric
# 2  461263600  https://www.airbnb.com/users/show/461263600   Tommaso
#
#    host_since host_location host_response_time  ... number_of_reviews  \
# 0  2023-01-10           NaN                NaN  ...                 0
# 1  2022-11-22           NaN     within an hour  ...                13
# 2  2022-05-27           NaN                NaN  ...                 0
#
#   review_scores_rating review_scores_accuracy review_scores_cleanliness  \
# 0                  NaN                    NaN                       NaN
# 1                 4.85                   4.77                      4.77
# 2                  NaN                    NaN                       NaN
#
#   review_scores_checkin review_scores_communication review_scores_location  \
# 0                   NaN                         NaN                    NaN
# 1                  4.85                        4.92                   4.85
# 2                   NaN                         NaN                    NaN
#
#   review_scores_value location_id neighbourhood_id
# 0                 NaN        2125               29
# 1                4.92        2859               29
# 2                 NaN           2              197
#
# [3 rows x 35 columns]

# %% [markdown]
# ### Wymiar listing

# %% [markdown]
# ##### Ekstrakcja danych

# %%
#wczytanie danych
df_listings = df[['id','listing_url', 'name', 'description','room_type', 'accommodates','bedrooms','beds','amenities', 'price', 'minimum_nights','maximum_nights', 'number_of_reviews', 'review_scores_rating', 'review_scores_accuracy', 'review_scores_cleanliness', 'review_scores_checkin', 'review_scores_communication','review_scores_location', 'review_scores_value']]

df_listings.head(3)
# Out:
#                    id                                      listing_url  \
# 0  801749842377802394  https://www.airbnb.com/rooms/801749842377802394
# 1  765948794133787266  https://www.airbnb.com/rooms/765948794133787266
# 2  636274456676328779  https://www.airbnb.com/rooms/636274456676328779
#
#                     name                                        description  \
# 0  A home away from home  The whole group will be comfortable in this sp...
# 1        Brooklyn Refuge    Take a break and unwind at this peaceful oasis.
# 2          Villa Masino.  Close to beach   Peaceful walk to park & beach...
#
#          room_type accommodates bedrooms beds  \
# 0     Private room            2        1    1
# 1     Private room            1        1    1
# 2  Entire home/apt            6        2    2
#
#                                            amenities    price minimum_nights  \
# 0  ["50\" TV", "Bathtub", "Microwave", "Free driv...  $143.00              2
# 1  ["Free parking on premises", "Carbon monoxide ...   $30.00              2
# 2  ["BBQ grill", "Security cameras on property", ...  $157.00              1
#
#   maximum_nights number_of_reviews review_scores_rating  \
# 0             30                 0                  NaN
# 1           1125                13                 4.85
# 2            365                 0                  NaN
#
#   review_scores_accuracy review_scores_cleanliness review_scores_checkin  \
# 0                    NaN                       NaN                   NaN
# 1                   4.77                      4.77                  4.85
# 2                    NaN                       NaN                   NaN
#
#   review_scores_communication review_scores_location review_scores_value
# 0                         NaN                    NaN                 NaN
# 1                        4.92                   4.85                4.92
# 2                         NaN                    NaN                 NaN

# %%
#wczytanie pliku sentymentow
df_sentiment = pd.read_csv('sentiment.csv', usecols=['listing', 'sentiment'])

df_sentiment.head()
# Out:
#               listing sentiment
# 0            48295887  POSITIVE
# 1            23018280  POSITIVE
# 2            13397316  POSITIVE
# 3             2298373  POSITIVE
# 4  572446396370094272  POSITIVE

# %%
#grupujemy po id i agregujemy sentymenty jako count of positive i count of negative
df_sentiment = df_sentiment.groupby(['listing', 'sentiment']).size().reset_index(name='count')

df_sentiment.head(20)
# Out:
#     listing sentiment  count
# 0      2595  NEGATIVE      1
# 1      2595  POSITIVE      3
# 2      5121  POSITIVE      2
# 3      5136  POSITIVE      1
# 4      5178  NEGATIVE      3
# 5      5178  POSITIVE     18
# 6      5203  POSITIVE      5
# 7      5586  POSITIVE      2
# 8      5803  POSITIVE      6
# 9      6848  POSITIVE      8
# 10     6990  POSITIVE      8
# 11     7097  NEGATIVE      1
# 12     7097  POSITIVE      9
# 13     7801  POSITIVE      1
# 14     8490  POSITIVE      5
# 15     9357  POSITIVE      5
# 16     9704  NEGATIVE      1
# 17     9704  POSITIVE      8
# 18    10452  POSITIVE      1
# 19    10962  POSITIVE      5

# %%
#tabela przestawna - pivot table
df_sentiment = df_sentiment.pivot(index='listing', columns='sentiment', values='count').reset_index()
#obsługa braków danych
df_sentiment = df_sentiment.fillna(0)

df_sentiment.head(10)
# Out:
# sentiment  listing  NEGATIVE  POSITIVE
# 0             2595       1.0       3.0
# 1             5121       0.0       2.0
# 2             5136       0.0       1.0
# 3             5178       3.0      18.0
# 4             5203       0.0       5.0
# 5             5586       0.0       2.0
# 6             5803       0.0       6.0
# 7             6848       0.0       8.0
# 8             6990       0.0       8.0
# 9             7097       1.0       9.0

# %%
#sprawdzamy duplikaty
df_sentiment.duplicated(subset=['listing']).sum()
# Out:
# 0

# %%
#merge tabeli listings i sentiment
df_listings = df_listings.astype({'id': 'int64'})
df_listings = pd.merge(df_listings, df_sentiment, left_on='id', right_on='listing', how='left')
df_listings = df_listings.drop(['listing'], axis=1)
df_listings.head(10)
# Out:
#                    id                                      listing_url  \
# 0  801749842377802394  https://www.airbnb.com/rooms/801749842377802394
# 1  765948794133787266  https://www.airbnb.com/rooms/765948794133787266
# 2  636274456676328779  https://www.airbnb.com/rooms/636274456676328779
# 3  768125251187660469  https://www.airbnb.com/rooms/768125251187660469
# 4            49248255            https://www.airbnb.com/rooms/49248255
# 5            52059982            https://www.airbnb.com/rooms/52059982
# 6  783379064435522892  https://www.airbnb.com/rooms/783379064435522892
# 7            39125813            https://www.airbnb.com/rooms/39125813
# 8  654508528815045267  https://www.airbnb.com/rooms/654508528815045267
# 9             6726337             https://www.airbnb.com/rooms/6726337
#
#                                                name  \
# 0                             A home away from home
# 1                                   Brooklyn Refuge
# 2                                     Villa Masino.
# 3         1-Bedroom Private Room with King Size Bed
# 4         Get the best of both worlds in Riverdale!
# 5                                            Room 1
# 6                                      Welcome home
# 7  Brand new construction nobody lived before 750sq
# 8        Room in Newly Renovated 4 Bedroom Townhome
# 9               Beautiful 2 Bedroom Apartment!! NYC
#
#                                          description        room_type  \
# 0  The whole group will be comfortable in this sp...     Private room
# 1    Take a break and unwind at this peaceful oasis.     Private room
# 2  Close to beach   Peaceful walk to park & beach...  Entire home/apt
# 3  Private room with king size bedroom near Sheep...     Private room
# 4  Welcome to the greatest location if you desire...  Entire home/apt
# 5  房间内带有两个标准的单人床，室内带有储藏室，宽敞舒适，氛围温馨。<br /><br /><b...     Private room
# 6  Disfruta de una experiencia con estilo en este...     Private room
# 7  The apartment is brand new and nobody has live...  Entire home/apt
# 8  Private, air-conditioned room in a newly renov...     Private room
# 9  Beautiful 2 bedroom Apartment!! it has everyth...  Entire home/apt
#
#   accommodates bedrooms beds  \
# 0            2        1    1
# 1            1        1    1
# 2            6        2    2
# 3            2        3    1
# 4            3        2    2
# 5            3        1    1
# 6            2        1    1
# 7            3        1    3
# 8            1        1    1
# 9            4        2    2
#
#                                            amenities    price  ...  \
# 0  ["50\" TV", "Bathtub", "Microwave", "Free driv...  $143.00  ...
# 1  ["Free parking on premises", "Carbon monoxide ...   $30.00  ...
# 2  ["BBQ grill", "Security cameras on property", ...  $157.00  ...
# 3  ["Security cameras on property", "Keypad", "Ca...   $89.00  ...
# 4  ["Hangers", "Clothing storage: closet", "Secur...  $125.00  ...
# 5  ["Hangers", "Bathtub", "Microwave", "Hot water...   $63.00  ...
# 6  ["Air conditioning", "Free parking on premises...   $82.00  ...
# 7  ["Hangers", "Kitchen", "Shampoo", "Heating", "...  $118.00  ...
# 8  ["Lock on bedroom door", "Air conditioning", "...   $49.00  ...
# 9  ["Hangers", "Bathtub", "Microwave", "Dishwashe...  $115.00  ...
#
#   number_of_reviews review_scores_rating review_scores_accuracy  \
# 0                 0                  NaN                    NaN
# 1                13                 4.85                   4.77
# 2                 0                  NaN                    NaN
# 3                15                  5.0                    5.0
# 4                25                 4.48                   4.56
# 5                40                 4.68                   4.88
# 6                 0                  NaN                    NaN
# 7                 3                  5.0                    5.0
# 8                 1                  5.0                    5.0
# 9                16                  5.0                   4.93
#
#   review_scores_cleanliness review_scores_checkin review_scores_communication  \
# 0                       NaN                   NaN                         NaN
# 1                      4.77                  4.85                        4.92
# 2                       NaN                   NaN                         NaN
# 3                      4.87                   5.0                         5.0
# 4                      4.44                  4.72                        4.88
# 5                      4.55                  4.78                        4.78
# 6                       NaN                   NaN                         NaN
# 7                       5.0                   5.0                         5.0
# 8                       5.0                   5.0                         5.0
# 9                      4.93                  4.93                        4.93
#
#   review_scores_location review_scores_value NEGATIVE POSITIVE
# 0                    NaN                 NaN      NaN      NaN
# 1                   4.85                4.92      0.0      1.0
# 2                    NaN                 NaN      NaN      NaN
# 3                    5.0                 5.0      0.0      1.0
# 4                   4.72                4.64      1.0      1.0
# 5                   4.93                4.68      0.0      1.0
# 6                    NaN                 NaN      NaN      NaN
# 7                    5.0                 5.0      NaN      NaN
# 8                    5.0                 5.0      NaN      NaN
# 9                    4.8                4.73      NaN      NaN
#
# [10 rows x 22 columns]

# %% [markdown]
# Identyfikacja anomalii

# %%
#weryfikujemy czy dane posiadaja założoną wartość
for col in df_listings.columns:
    print(col, df_listings[col].unique())
# Out:
# id [801749842377802394 765948794133787266 636274456676328779 ...
#            52491515           48158801           48316258]
# listing_url ['https://www.airbnb.com/rooms/801749842377802394'
#  'https://www.airbnb.com/rooms/765948794133787266'
#  'https://www.airbnb.com/rooms/636274456676328779' ...
#  'https://www.airbnb.com/rooms/52491515'
#  'https://www.airbnb.com/rooms/48158801'
#  'https://www.airbnb.com/rooms/48316258']
# name ['A home away from home' 'Brooklyn Refuge' 'Villa Masino.' ...
#  'Cozy 3 bedroom apt in the heart of Lower East Side'
#  'Spacious Loft Space / Photo studio in Bushwick'
#  'Sonder Flatiron | Spacious King Room+']
# description ['The whole group will be comfortable in this spacious and unique space.<br /><br /><b>Guest access</b><br />you can enjoy the living room, dining room, kitchen and the backyard. The home has two entrances'
#  'Take a break and unwind at this peaceful oasis.'
#  'Close to beach   Peaceful walk to park & beach .close to shopping' ...
#  "Location Location. Hell's Kitchen, Times Square, clean, spacious 2 bedroom flat , perfect for families , couples, friends etc<br /><br /><b>The space</b><br />Location Location. Hell's Kitchen, Times Square, clean, spacious 2 bedroom flat , perfect for families , couples, friends etc<br /><br />Note :  photos are  current and represent layout and bedding configuration, new painting in kitchen as of  second part of June when we did some remodeling <br /><br />Located in very vibrant part of Midtown Manhattan with tons of bars and restaurants, with Central Park, Times Square as the nearest attractions <br />Basics about this flat:<br />2 bedrooms with queen beds in each, living room with sofa bed, TV, wifi , all bedding is provided //  kitchen with dinning set and cooking pots and pans , dinning table with chairs.<br />The bathroom has shower tub, hair dryer, towels are provided as well <br /><br />if possible, bags can be dropped before regular check-in  time at 3 PM  Checkout is 11 AM"
#  'This comfortable apartment in the heart of Lower East Side of Manhattan will meet all your needs coming to NY. It is equipped with everything you need for a comfortable extended stay plus high speed internet dedicated for this unit. It comes with living room and separate area for dinning. Walk to Soho and all downtown in just a few minutes or take the train just steps away.'
#  'Looking for a two month subleter. LGBTQ+ and allies friendly.<br /><br />The loft is spacious, with an open kitchen and living room, two bathrooms, a rooftop. And in addition, the building has an area to park bikes. <br /><br />You will be sharing the space with 5 other people. Most work full time and are rarely home. <br /><br />Looking forward to hearing from you! Price is negotiable.']
# room_type ['Private room' 'Entire home/apt' 'Shared room' 'Hotel room']
# accommodates ['2' '1' '6' '3' '4' '7' '5' '12' '15' '8' '16' '14' '10' '13' '9' '11'
#  '0']
# bedrooms ['1' '2' '3' nan '4' '6' '5' '7' '11' '9' '8' '16' '14']
# beds ['1' '2' '3' '5' '4' nan '6' '7' '8' '9' '10' '12' '13' '11' '21' '16'
#  '18' '17' '14' '42']
# amenities ['["50\\" TV", "Bathtub", "Microwave", "Free driveway parking on premises", "Laundromat nearby", "Kitchen", "Refrigerator", "Central air conditioning", "Smoke alarm", "Central heating", "Free street parking", "Clothing storage: closet and walk-in closet", "Essentials", "Carbon monoxide alarm", "Dining table", "Stainless steel oven", "Wifi", "Ceiling fan", "Dedicated workspace", "Gas stove", "Cooking basics", "Private backyard", "Hot water kettle", "Bed linens", "Hot water"]'
#  '["Free parking on premises", "Carbon monoxide alarm", "First aid kit", "Wifi", "TV", "Smoke alarm", "Kitchen"]'
#  '["BBQ grill", "Security cameras on property", "Fire pit"]' ...
#  '["Hangers", "Dishes and silverware", "Lockbox", "Bathtub", "Cooking basics", "Carbon monoxide alarm", "Pets allowed", "Radiant heating", "Wifi", "Self check-in", "Smoke alarm", "Dedicated workspace", "Bed linens", "Kitchen", "Essentials"]'
#  '["Lock on bedroom door", "Fire extinguisher", "Kitchen", "Free parking on premises", "Shampoo", "Heating", "Carbon monoxide alarm", "Pets allowed", "First aid kit", "Wifi", "Smoke alarm", "Smoking allowed", "Hot water", "Essentials"]'
#  '["Hangers", "Air conditioning", "Fast wifi \\u2013 313 Mbps", "Shampoo", "Heating", "Microwave", "Coffee maker", "Hair dryer", "TV", "Smoke alarm", "Bed linens", "Hot water", "Elevator", "Essentials", "Iron"]']
# price ['$143.00' '$30.00' '$157.00' ... '$1,131.00' '$754.00' '$1,271.00']
# minimum_nights ['2' '1' '3' '7' '5' '30' '4' '31' '6' '50' '90' '25' '10' '100' '33' '8'
#  '15' '365' '500' '13' '12' '14' '45' '29' '60' '20' '28' '59' '270' '21'
#  '75' '85' '27' '180' '35' '89' '9' '150' '364' '184' '356' '300' '16'
#  '32' '18' '80' '24' '120' '55' '70' '200' '56' '99' '999' '133' '1000'
#  '38' '11' '40' '185' '360' '22' '36' '400' '53' '91' '19' '86' '240'
#  '186' '304' '265' '169' '160' '210' '130' '1250' '26' '181' '108' '115'
#  '46' '182' '39' '370' '93' '17' '58' '79' '280' '76' '65' '238' '345'
#  '92' '98' '140' '250' '273' '110' '68' '62' '88' '63' '199' '1124' '23'
#  '222' '94' '48' '145' '64' '78' '119' '153' '96' '52' '114' '259' '366'
#  '198' '480' '307' '299' '183' '43' '310' '244']
# maximum_nights ['30' '1125' '365' '20' '21' '60' '5' '31' '62' '28' '7' '13' '180' '29'
#  '70' '270' '10' '90' '15' '3' '730' '40' '200' '25' '2' '360' '750' '160'
#  '14' '34' '12' '18' '330' '27' '100' '1' '367' '300' '35' '26' '3000'
#  '45' '120' '183' '1000' '4' '75' '500' '540' '800' '11' '1122' '1124' '8'
#  '260' '32' '63' '185' '22' '85' '364' '61' '17' '99' '345' '93' '278'
#  '80' '181' '240' '130' '170' '150' '6' '37' '372' '50' '366' '126' '140'
#  '9' '92' '38' '56' '184' '132' '19' '700' '36' '89' '999' '55' '96' '165'
#  '20000000' '24' '731' '110' '42' '190' '356' '250' '210' '91' '135' '400'
#  '104' '325' '59' '41' '101' '2147483647' '1100' '1123' '44' '65' '16'
#  '121' '9999' '33' '149' '600' '900' '68' '173' '1114' '363' '125' '182'
#  '39' '23' '69' '58' '186' '335' '53' '95' '720' '555' '84' '2000' '350'
#  '355' '88' '54' '279' '220' '66' '108' '115' '1105' '49' '74' '10000'
#  '64' '102' '299' '175' '1111' '349' '78' '43' '187' '152' '161' '275'
#  '333' '1250' '106' '444' '1120' '105' '298' '124' '122' '368' '123' '370'
#  '1001' '1080' '930' '376' '490' '1126' '371' '480' '72' '47' '156' '188'
#  '353' '450' '112' '76' '395' '73' '107' '362' '97' '238' '361' '67' '375'
#  '117' '98' '398' '213' '249' '212' '369' '1083' '290' '116' '518' '352'
#  '6000' '218' '1047' '148' '77' '399' '760' '94' '51' '1119' '232' '155'
#  '357' '103' '215' '225' '48' '280' '158' '1121' '82' '254' '224' '114'
#  '259' '340' '1107' '83' '243' '57' '332' '1097' '725' '129' '358' '163'
#  '199' '295' '380' '178' '244']
# number_of_reviews ['0' '13' '15' '25' '40' '3' '1' '16' '2' '17' '6' '8' '77' '86' '18' '7'
#  '26' '135' '41' '187' '4' '32' '29' '89' '23' '124' '178' '43' '94' '12'
#  '408' '73' '54' '10' '48' '9' '34' '67' '153' '324' '5' '35' '42' '20'
#  '78' '36' '50' '92' '14' '183' '72' '21' '76' '33' '44' '47' '70' '75'
#  '53' '19' '38' '11' '71' '52' '28' '163' '330' '63' '128' '121' '39' '56'
#  '186' '80' '22' '149' '119' '61' '31' '93' '95' '139' '175' '27' '37'
#  '59' '132' '123' '205' '141' '45' '254' '100' '158' '96' '173' '293'
#  '202' '74' '46' '150' '88' '131' '228' '51' '87' '107' '212' '55' '62'
#  '60' '143' '85' '64' '83' '191' '113' '30' '65' '269' '57' '246' '182'
#  '24' '250' '148' '342' '104' '315' '204' '142' '49' '179' '97' '101'
#  '125' '133' '152' '305' '68' '192' '58' '277' '118' '138' '105' '115'
#  '414' '200' '114' '194' '82' '359' '127' '280' '331' '116' '174' '120'
#  '321' '151' '98' '273' '147' '433' '199' '69' '262' '160' '91' '126'
#  '157' '313' '295' '193' '245' '84' '298' '140' '195' '257' '90' '110'
#  '161' '220' '188' '66' '170' '241' '112' '111' '328' '176' '264' '213'
#  '746' '230' '167' '102' '79' '203' '156' '177' '206' '146' '481' '145'
#  '106' '207' '185' '166' '99' '234' '130' '117' '165' '129' '184' '109'
#  '103' '172' '249' '164' '168' '312' '144' '181' '244' '108' '251' '288'
#  '240' '284' '274' '219' '255' '352' '229' '221' '189' '243' '201' '597'
#  '766' '180' '81' '366' '667' '423' '319' '155' '532' '490' '215' '1097'
#  '372' '281' '227' '122' '248' '217' '218' '450' '291' '285' '575' '278'
#  '385' '136' '214' '386' '519' '137' '489' '154' '238' '258' '268' '275'
#  '231' '198' '320' '392' '239' '425' '1842' '261' '985' '306' '544' '197'
#  '451' '448' '294' '196' '134' '225' '430' '216' '263' '333' '304' '732'
#  '223' '303' '308' '162' '373' '159' '300' '247' '286' '211' '279' '438'
#  '655' '171' '763' '226' '380' '253' '523' '272' '271' '287' '536' '346'
#  '252' '259' '210' '232' '208' '310' '190' '237' '323' '301' '242' '654'
#  '299' '337' '282' '471' '502' '358' '222' '361' '357' '233' '309' '265'
#  '397' '374' '492' '369' '480' '434' '317' '260' '543' '169' '420' '511'
#  '464' '516' '344' '336' '209' '421' '370' '334' '224' '547' '314' '436'
#  '355' '442' '396' '296' '789' '494' '276' '387' '404' '375' '424' '395'
#  '322' '403' '311' '307' '236' '1642' '493' '1010' '463' '345' '267' '325'
#  '377' '235' '290' '522' '531' '453' '533' '382' '389' '483' '473' '347'
#  '343' '351' '368' '507' '302' '376' '426' '948' '270' '603' '398' '415'
#  '467' '401' '297' '452' '379' '458' '348' '520' '583' '558' '619' '427'
#  '510' '335' '488' '917' '371' '338' '318' '327' '360' '422' '629' '548'
#  '479' '350' '529' '646' '356' '418' '341' '593' '462' '256' '329' '580'
#  '292' '620' '586' '591' '410' '363' '407' '491' '393' '394' '354' '283'
#  '383' '266' '798' '384' '289']
# review_scores_rating [nan '4.85' '5.0' '4.48' '4.68' '4.76' '4.88' '4.61' '4.54' '4.83' '4.67'
#  '4.31' '4.95' '4.94' '4.71' '4.73' '4.74' '4.75' '4.87' '4.69' '4.8'
#  '4.41' '4.17' '4.7' '4.79' '4.93' '4.33' '4.5' '4.0' '4.66' '4.86' '4.91'
#  '4.96' '4.47' '3.8' '3.33' '3.14' '4.65' '4.78' '4.57' '4.9' '4.24'
#  '4.64' '4.81' '4.3' '4.28' '4.62' '4.6' '4.82' '4.52' '4.92' '4.59'
#  '4.29' '4.72' '4.16' '4.42' '4.77' '3.5' '4.45' '4.4' '1.0' '4.56' '4.89'
#  '4.46' '4.51' '4.2' '4.84' '4.25' '0.0' '4.98' '4.97' '3.0' '4.14' '3.67'
#  '4.32' '4.55' '2.0' '4.58' '4.36' '3.75' '4.38' '4.63' '4.49' '4.23'
#  '4.99' '4.1' '3.89' '4.34' '2.75' '3.77' '4.26' '3.56' '4.44' '4.27'
#  '1.5' '3.88' '4.43' '2.5' '3.2' '3.25' '2.86' '4.53' '4.39' '4.37' '4.03'
#  '3.86' '4.13' '4.05' '4.06' '4.18' '4.21' '4.22' '4.09' '3.73' '3.55'
#  '1.33' '3.71' '4.11' '4.35' '3.17' '3.83' '4.12' '3.57' '4.08' '3.94'
#  '4.07' '2.67' '3.92' '3.87' '2.33' '3.43' '3.7' '4.15' '3.4' '4.04'
#  '3.95' '4.19' '2.83' '3.29' '4.02' '3.9' '3.97' '3.6' '3.76' '3.36'
#  '3.63' '3.81' '3.96' '3.84' '3.79' '3.91' '3.85' '3.61' '3.27' '2.6'
#  '3.78' '3.64' '3.58' '3.93' '3.3' '3.98' '2.25' '3.1' '3.38' '3.21'
#  '3.45' '3.65' '3.68' '3.99' '3.13' '3.54' '1.75' '2.89']
# review_scores_accuracy [nan '4.77' '5.0' '4.56' '4.88' '4.93' '4.82' '4.83' '4.62' '4.97' '4.94'
#  '4.86' '4.81' '4.8' '4.75' '4.34' '4.24' '4.67' '4.68' '4.99' '4.33'
#  '4.44' '4.64' '4.58' '4.95' '4.89' '4.9' '3.5' '4.96' '4.84' '4.11'
#  '4.61' '3.8' '4.91' '4.74' '4.0' '4.6' '4.92' '4.55' '4.79' '4.76' '4.2'
#  '4.5' '4.65' '4.39' '4.14' '4.69' '4.17' '4.98' '4.16' '4.42' '4.78'
#  '4.73' '4.85' '3.75' '4.71' '4.48' '4.4' '1.5' '4.66' '4.63' '4.47'
#  '4.87' '1.0' '4.7' '4.45' '2.67' '3.0' '4.53' '4.26' '2.0' '4.3' '4.72'
#  '4.43' '4.29' '4.57' '4.22' '4.08' '4.23' '3.33' '4.54' '4.46' '3.63'
#  '4.35' '4.41' '4.52' '4.19' '2.5' '3.67' '2.8' '2.43' '4.32' '4.49'
#  '3.97' '4.38' '4.09' '4.51' '4.36' '4.25' '4.15' '4.37' '3.86' '4.31'
#  '3.88' '4.21' '4.1' '4.06' '4.28' '4.59' '3.94' '3.6' '3.64' '1.33'
#  '4.27' '3.83' '4.18' '3.92' '0.0' '4.13' '4.04' '2.33' '3.89' '3.9'
#  '3.71' '2.75' '2.71' '3.95' '3.79' '3.4' '1.67' '3.25' '4.12' '3.93'
#  '3.76' '4.05' '4.07' '2.6' '3.27' '4.03' '3.78' '3.55' '3.73' '3.57'
#  '3.82' '3.85' '4.02' '2.83' '3.29' '3.36' '3.2' '3.14' '3.45' '3.58'
#  '3.91' '3.74' '3.17' '3.43' '3.96' '3.68' '3.56' '3.98']
# review_scores_cleanliness [nan '4.77' '4.87' '4.44' '4.55' '5.0' '4.93' '4.88' '4.83' '4.31' '4.67'
#  '4.46' '4.5' '4.97' '4.86' '4.54' '4.85' '4.78' '4.9' '4.75' '4.8' '4.59'
#  '4.45' '4.94' '4.53' '4.0' '4.33' '4.76' '4.96' '4.91' '4.7' '4.56' '4.3'
#  '3.2' '3.86' '4.28' '4.89' '4.22' '4.98' '4.38' '4.52' '4.92' '4.64'
#  '4.43' '4.84' '4.81' '4.37' '4.34' '4.73' '3.0' '4.6' '3.75' '4.71'
#  '4.49' '1.0' '4.61' '3.83' '4.66' '4.4' '4.32' '4.99' '4.74' '4.82' '2.0'
#  '4.41' '4.65' '3.5' '3.67' '4.39' '4.29' '4.35' '4.58' '4.79' '4.95'
#  '4.69' '4.57' '4.63' '4.2' '4.47' '4.42' '4.27' '4.1' '4.17' '4.62'
#  '4.25' '4.51' '4.07' '4.48' '4.12' '4.14' '4.18' '4.21' '4.68' '2.67'
#  '4.24' '3.56' '3.33' '4.19' '4.11' '4.23' '4.09' '3.89' '4.36' '3.94'
#  '3.88' '3.9' '2.5' '4.04' '2.8' '3.25' '3.98' '2.71' '4.13' '3.82' '3.97'
#  '3.71' '3.69' '4.72' '4.26' '3.68' '3.92' '3.84' '4.08' '3.74' '3.49'
#  '3.72' '3.63' '3.8' '3.6' '2.73' '3.93' '3.64' '2.2' '4.02' '3.58' '3.38'
#  '3.81' '3.4' '4.05' '3.44' '3.29' '4.15' '3.78' '0.0' '2.33' '2.86'
#  '1.33' '3.52' '2.95' '3.65' '3.46' '3.43' '3.79' '3.77' '1.8' '3.57'
#  '4.06' '3.21' '1.5' '3.47' '3.91' '3.51' '3.85' '2.75' '4.03' '3.17'
#  '1.67' '3.7' '3.36' '3.95' '3.14' '2.43' '3.3' '2.25' '3.39' '4.16'
#  '3.35' '3.76' '3.73' '3.31' '3.18' '1.75' '3.61' '3.87' '3.23' '2.6'
#  '3.45' '3.53' '2.83' '3.62' '3.96' '2.64' '2.89' '3.27' '3.59' '3.32'
#  '3.99' '3.66' '2.4' '3.07' '3.55' '2.63']
# review_scores_checkin [nan '4.85' '5.0' '4.72' '4.78' '4.93' '4.83' '4.88' '4.62' '4.69' '4.0'
#  '4.95' '4.57' '4.92' '4.82' '4.75' '4.87' '4.76' '4.9' '4.91' '4.97'
#  '4.89' '4.5' '4.81' '4.8' '4.94' '4.96' '4.56' '4.2' '3.33' '3.71' '4.6'
#  '4.71' '4.7' '4.33' '4.79' '4.43' '4.44' '4.67' '4.86' '4.68' '4.26'
#  '3.63' '4.59' '1.0' '4.73' '4.98' '4.77' '4.84' '4.66' '4.99' '4.63'
#  '4.4' '3.5' '3.0' '4.61' '4.25' '4.74' '4.65' '3.75' '4.53' '4.47' '4.58'
#  '4.11' '3.62' '4.46' '4.54' '3.67' '4.38' '4.45' '4.28' '3.8' '4.3' '2.0'
#  '4.19' '4.22' '3.43' '4.42' '4.64' '4.52' '4.1' '4.29' '4.36' '4.31'
#  '4.09' '4.55' '4.16' '3.94' '4.35' '4.12' '4.37' '4.18' '1.5' '4.17'
#  '4.23' '2.33' '4.27' '3.83' '2.67' '3.6' '4.14' '4.48' '4.51' '4.08'
#  '0.0' '4.15' '4.21' '4.39' '4.41' '3.93' '1.33' '2.75' '4.49' '4.03'
#  '3.4' '3.86' '3.25' '3.95' '3.57' '2.5' '4.24' '3.9' '4.07' '4.32' '4.34'
#  '4.05' '3.89' '4.13' '3.17' '3.56' '4.06' '2.83' '3.82' '3.88' '3.36'
#  '3.78' '2.8' '3.29' '3.73' '3.81' '3.91' '3.2' '3.7' '3.96']
# review_scores_communication [nan '4.92' '5.0' '4.88' '4.78' '4.93' '4.82' '4.9' '4.77' '4.83' '4.54'
#  '4.95' '4.94' '4.89' '4.86' '4.96' '4.72' '4.69' '4.62' '4.58' '4.67'
#  '4.65' '4.87' '4.85' '4.79' '4.8' '4.98' '3.5' '4.11' '4.64' '4.0' '4.97'
#  '4.74' '3.33' '4.91' '4.1' '3.94' '4.61' '4.44' '4.99' '4.75' '4.29'
#  '4.68' '4.73' '4.33' '4.21' '4.48' '1.5' '4.71' '3.8' '4.84' '4.5' '4.42'
#  '4.81' '4.7' '4.6' '4.47' '3.0' '4.63' '4.76' '2.0' '4.57' '4.4' '4.3'
#  '1.0' '4.43' '4.25' '3.86' '4.2' '4.56' '4.59' '4.46' '3.67' '4.08'
#  '4.22' '3.75' '4.34' '4.32' '4.55' '4.06' '2.8' '2.5' '4.38' '3.89'
#  '2.57' '3.6' '4.31' '4.18' '4.45' '4.19' '3.91' '4.53' '4.17' '4.13'
#  '4.24' '4.52' '4.16' '4.39' '4.37' '4.51' '3.82' '4.01' '3.4' '4.15'
#  '4.66' '4.27' '4.49' '4.12' '4.41' '3.17' '2.67' '3.95' '0.0' '4.26'
#  '3.62' '4.28' '3.74' '4.07' '2.75' '1.67' '3.57' '4.23' '4.36' '3.97'
#  '3.63' '3.25' '4.14' '4.35' '3.81' '2.6' '4.02' '2.33' '3.9' '4.05'
#  '4.09' '3.92' '3.83' '3.78' '3.58' '3.96' '3.71' '3.2' '3.47' '3.36'
#  '3.22' '2.7' '3.43' '3.59' '3.38' '4.04' '3.88' '4.03' '3.93' '2.25'
#  '3.99' '3.85' '3.84']
# review_scores_location [nan '4.85' '5.0' '4.72' '4.93' '4.8' '4.24' '4.83' '4.88' '4.82' '4.46'
#  '4.38' '4.0' '4.99' '4.78' '4.43' '4.77' '4.64' '4.73' '4.74' '4.75'
#  '4.67' '4.53' '4.52' '4.36' '4.87' '4.81' '4.89' '4.95' '4.33' '4.56'
#  '4.92' '4.58' '4.76' '4.9' '4.5' '4.94' '4.91' '3.0' '4.62' '3.2' '4.79'
#  '3.57' '4.35' '4.4' '4.7' '4.47' '4.57' '4.71' '4.3' '4.86' '4.22' '4.29'
#  '4.39' '4.44' '4.55' '4.32' '4.45' '3.38' '4.34' '4.68' '4.69' '1.0'
#  '4.17' '4.49' '4.54' '4.6' '4.48' '4.65' '4.59' '4.61' '4.63' '4.84'
#  '4.25' '4.37' '4.96' '2.5' '3.9' '4.05' '3.5' '4.2' '4.1' '4.14' '4.28'
#  '4.66' '4.41' '4.16' '3.67' '4.42' '3.8' '4.98' '4.26' '4.97' '4.18'
#  '3.81' '4.51' '4.11' '4.19' '3.75' '4.15' '3.44' '3.33' '3.25' '4.31'
#  '4.13' '3.86' '3.92' '2.8' '1.5' '3.95' '3.89' '4.27' '4.01' '4.23'
#  '3.71' '4.21' '4.06' '4.09' '3.88' '2.0' '3.6' '3.83' '3.82' '3.4' '3.76'
#  '3.15' '4.08' '3.56' '2.67' '4.07' '3.93' '3.97' '4.03' '0.0' '2.33'
#  '3.64' '4.04' '3.87' '3.85' '3.79' '3.94' '3.69' '3.91' '4.12' '3.43'
#  '3.73' '3.29' '3.84' '3.68' '3.74' '2.83' '3.96' '3.98' '3.13' '3.63'
#  '3.3' '3.78' '3.99' '2.86' '4.02' '3.42' '3.17' '3.54' '3.7']
# review_scores_value [nan '4.92' '5.0' '4.64' '4.68' '4.73' '4.82' '4.83' '4.75' '4.38' '4.54'
#  '4.9' '4.88' '4.57' '4.65' '4.78' '4.67' '4.8' '4.66' '4.87' '4.52'
#  '4.12' '4.7' '4.81' '4.77' '4.91' '4.33' '4.89' '4.5' '4.71' '4.58' '4.0'
#  '4.62' '4.63' '4.6' '3.5' '4.59' '4.44' '4.85' '3.6' '3.0' '4.72' '4.94'
#  '4.32' '4.4' '4.95' '4.86' '4.49' '4.99' '4.55' '4.74' '4.47' '4.69'
#  '3.25' '4.96' '4.31' '1.0' '4.17' '4.2' '4.76' '4.53' '4.15' '4.34'
#  '4.79' '4.61' '4.22' '4.56' '2.67' '4.35' '4.84' '2.0' '4.43' '4.46'
#  '4.93' '4.36' '3.75' '2.33' '2.5' '4.1' '4.14' '3.67' '4.24' '4.42'
#  '4.13' '4.25' '4.98' '4.29' '4.48' '4.11' '3.92' '3.56' '3.4' '4.19'
#  '3.63' '4.16' '3.29' '4.18' '4.3' '4.45' '4.37' '4.06' '4.27' '4.97'
#  '3.83' '3.33' '2.8' '1.5' '4.03' '4.26' '3.86' '4.51' '4.21' '4.41'
#  '4.04' '3.64' '4.07' '4.39' '3.8' '3.36' '4.09' '3.71' '3.54' '3.78'
#  '4.08' '4.28' '0.0' '3.69' '3.93' '3.3' '2.83' '3.43' '3.9' '3.88' '3.57'
#  '3.84' '3.96' '3.76' '3.68' '3.91' '2.75' '3.7' '3.89' '3.72' '3.95'
#  '4.23' '3.82' '3.55' '3.97' '3.73' '3.87' '2.6' '3.79' '4.05' '3.85'
#  '3.94' '2.25' '3.2' '3.45' '3.13' '3.1' '3.14' '3.98' '3.42' '4.02'
#  '3.77' '3.81' '3.17']
# NEGATIVE [nan  0.  1.  3.  2.  4. 14.  7.  5.  6.  9. 11.]
# POSITIVE [nan  1.  2.  3.  4.  8.  5.  6. 17. 11.  7. 13.  0.  9. 10. 12. 22. 16.
#  14. 15. 26. 21. 18. 20. 29. 24. 33. 25. 66. 38. 19. 36. 31. 28. 23. 58.
#  44. 47. 30. 35.]

# %%
#sprawdzamy puste wartości
df_listings.isnull().sum()
# Out:
# id                                 0
# listing_url                        0
# name                              12
# description                      753
# room_type                          0
# accommodates                       0
# bedrooms                        3874
# beds                             929
# amenities                          0
# price                              0
# minimum_nights                     0
# maximum_nights                     0
# number_of_reviews                  0
# review_scores_rating           10304
# review_scores_accuracy         10739
# review_scores_cleanliness      10729
# review_scores_checkin          10743
# review_scores_communication    10734
# review_scores_location         10746
# review_scores_value            10746
# NEGATIVE                       28034
# POSITIVE                       28034
# dtype: int64

# %%
#sprawdzamy atrubuty
df_listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 42931 entries, 0 to 42930
# Data columns (total 22 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           42931 non-null  int64
#  1   listing_url                  42931 non-null  object
#  2   name                         42919 non-null  object
#  3   description                  42178 non-null  object
#  4   room_type                    42931 non-null  object
#  5   accommodates                 42931 non-null  object
#  6   bedrooms                     39057 non-null  object
#  7   beds                         42002 non-null  object
#  8   amenities                    42931 non-null  object
#  9   price                        42931 non-null  object
#  10  minimum_nights               42931 non-null  object
#  11  maximum_nights               42931 non-null  object
#  12  number_of_reviews            42931 non-null  object
#  13  review_scores_rating         32627 non-null  object
#  14  review_scores_accuracy       32192 non-null  object
#  15  review_scores_cleanliness    32202 non-null  object
#  16  review_scores_checkin        32188 non-null  object
#  17  review_scores_communication  32197 non-null  object
#  18  review_scores_location       32185 non-null  object
#  19  review_scores_value          32185 non-null  object
#  20  NEGATIVE                     14897 non-null  float64
#  21  POSITIVE                     14897 non-null  float64
# dtypes: float64(2), int64(1), object(19)
# memory usage: 7.5+ MB

# %%
#sprawdzamy duplikaty
df_listings.duplicated().sum()
# Out:
# 0

# %%
#check for outliers
df_listings.describe()
# Out:
#                  id      NEGATIVE      POSITIVE
# count  4.293100e+04  14897.000000  14897.000000
# mean   2.222772e+17      0.204941      3.039740
# std    3.344213e+17      0.529558      3.466663
# min    2.595000e+03      0.000000      0.000000
# 25%    1.940474e+07      0.000000      1.000000
# 50%    4.337482e+07      0.000000      2.000000
# 75%    6.305016e+17      0.000000      4.000000
# max    8.404660e+17     14.000000     66.000000

# %% [markdown]
# Transformacja danych

# %%
#zmiana nazw kolumny id na listing_id
df_listings = df_listings.rename(columns={'id': 'listing_id', 'NEGATIVE' : 'count_of_negative', 'POSITIVE' : 'count_of_positive'})

# %%
#obsluga brakujacych danych
df_listings['name'] = df_listings['name'].fillna('unknown')
df_listings['description'] = df_listings['description'].fillna('unknown')
df_listings['bedrooms'] = df_listings['bedrooms'].fillna(-1)
df_listings['beds'] = df_listings['beds'].fillna(-1)
df_listings['review_scores_rating'] = df_listings['review_scores_rating'].fillna(-1)
df_listings['review_scores_accuracy'] = df_listings['review_scores_accuracy'].fillna(-1)
df_listings['review_scores_cleanliness'] = df_listings['review_scores_cleanliness'].fillna(-1)
df_listings['review_scores_checkin'] = df_listings['review_scores_checkin'].fillna(-1)
df_listings['review_scores_communication'] = df_listings['review_scores_communication'].fillna(-1)
df_listings['review_scores_location'] = df_listings['review_scores_location'].fillna(-1)
df_listings['review_scores_value'] = df_listings['review_scores_value'].fillna(-1)
df_listings['count_of_negative'] = df_listings['count_of_negative'].fillna(-1)
df_listings['count_of_positive'] = df_listings['count_of_positive'].fillna(-1)

#sprawdzamy puste wartości
df_listings.isnull().sum()
# Out:
# listing_id                     0
# listing_url                    0
# name                           0
# description                    0
# room_type                      0
# accommodates                   0
# bedrooms                       0
# beds                           0
# amenities                      0
# price                          0
# minimum_nights                 0
# maximum_nights                 0
# number_of_reviews              0
# review_scores_rating           0
# review_scores_accuracy         0
# review_scores_cleanliness      0
# review_scores_checkin          0
# review_scores_communication    0
# review_scores_location         0
# review_scores_value            0
# count_of_negative              0
# count_of_positive              0
# dtype: int64

# %%
#usuwanie znaków specjalnych z kolumny price
df_listings['price'] = df_listings['price'].str.replace('$', '')
df_listings['price'] = df_listings['price'].str.replace(',', '')
#amenities
df_listings['amenities'] = df_listings['amenities'].str.replace('{', '')
df_listings['amenities'] = df_listings['amenities'].str.replace('}', '')
df_listings['amenities'] = df_listings['amenities'].str.replace('"', '')
df_listings['amenities'] = df_listings['amenities'].str.replace('/', '')
#description
df_listings['description'] = df_listings['description'].str.replace('<br />', '')
df_listings['description'] = df_listings['description'].str.replace('<b>', '')
df_listings['description'] = df_listings['description'].str.replace('</b>', '')
df_listings['description'] = df_listings['description'].str.replace('<p>', '')
df_listings['description'] = df_listings['description'].str.replace('</p>', '')
df_listings['description'] = df_listings['description'].str.replace('<strong>', '')
df_listings['description'] = df_listings['description'].str.replace('</strong>', '')
df_listings['description'] = df_listings['description'].str.replace('<br>', '')
df_listings['description'] = df_listings['description'].str.replace('<br/>', '')
# Out:
# C:\Users\dabro\AppData\Local\Temp\ipykernel_4328\999651480.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_listings['price'] = df_listings['price'].str.replace('$', '')
# C:\Users\dabro\AppData\Local\Temp\ipykernel_4328\999651480.py:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_listings['amenities'] = df_listings['amenities'].str.replace('{', '')
# C:\Users\dabro\AppData\Local\Temp\ipykernel_4328\999651480.py:6: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_listings['amenities'] = df_listings['amenities'].str.replace('}', '')

# %%
#zmiana typu danych
numeric_columns = ['listing_id', 'accommodates', 'bedrooms', 'beds', 'minimum_nights', 'maximum_nights', 'number_of_reviews', 'count_of_negative', 'count_of_positive']
float_columns = ['price','review_scores_rating', 'review_scores_accuracy', 'review_scores_cleanliness', 'review_scores_checkin', 'review_scores_communication', 'review_scores_location', 'review_scores_value']
text_columns = ['listing_url', 'name', 'description', 'amenities', 'room_type']

def change_type_to_int(df, col):
    df[col] = df[col].astype('int64')
    return df

def change_type_to_float(df, col):
    df[col] = df[col].astype('float64')
    return df

def change_type_to_str(df, col):
    df[col] = df[col].astype(pd.StringDtype())
    return df

for col in numeric_columns:
    try:
        df_listings = change_type_to_int(df_listings, col)
    except:
        print(f"Nie udało się zmienić typu danych kolumny {col} na int64")

for col in text_columns:
    try: 
        df_listings = change_type_to_str(df_listings, col)
    except:
        print(f"Nie udało się zmienić typu danych kolumny {col} na String")
   
for col in float_columns:
    try: 
        df_listings = change_type_to_float(df_listings, col)
    except:
        print(f"Nie udało się zmienić typu danych kolumny {col} na float64")

df_listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 42931 entries, 0 to 42930
# Data columns (total 22 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   listing_id                   42931 non-null  int64
#  1   listing_url                  42931 non-null  string
#  2   name                         42931 non-null  string
#  3   description                  42931 non-null  string
#  4   room_type                    42931 non-null  string
#  5   accommodates                 42931 non-null  int64
#  6   bedrooms                     42931 non-null  int64
#  7   beds                         42931 non-null  int64
#  8   amenities                    42931 non-null  string
#  9   price                        42931 non-null  float64
#  10  minimum_nights               42931 non-null  int64
#  11  maximum_nights               42931 non-null  int64
#  12  number_of_reviews            42931 non-null  int64
#  13  review_scores_rating         42931 non-null  float64
#  14  review_scores_accuracy       42931 non-null  float64
#  15  review_scores_cleanliness    42931 non-null  float64
#  16  review_scores_checkin        42931 non-null  float64
#  17  review_scores_communication  42931 non-null  float64
#  18  review_scores_location       42931 non-null  float64
#  19  review_scores_value          42931 non-null  float64
#  20  count_of_negative            42931 non-null  int64
#  21  count_of_positive            42931 non-null  int64
# dtypes: float64(8), int64(9), string(5)
# memory usage: 7.5 MB

# %%
#sprawdzamy czy nie ma danych numerycznych poza założonym przedziałem
def print_stats(df, column):
    stats = column.describe()
    return stats

for col in float_columns:
    print(col,"\n", print_stats(df_listings, df_listings[col]), "\n")
# Out:
# price
#  count    42931.000000
# mean       200.307167
# std        895.082911
# min          0.000000
# 25%         75.000000
# 50%        125.000000
# 75%        200.000000
# max      99000.000000
# Name: price, dtype: float64
#
# review_scores_rating
#  count    42931.000000
# mean         3.283620
# std          2.487474
# min         -1.000000
# 25%          1.000000
# 50%          4.700000
# 75%          4.950000
# max          5.000000
# Name: review_scores_rating, dtype: float64
#
# review_scores_accuracy
#  count    42931.000000
# mean         3.311382
# std          2.523072
# min         -1.000000
# 25%         -1.000000
# 50%          4.790000
# 75%          5.000000
# max          5.000000
# Name: review_scores_accuracy, dtype: float64
#
# review_scores_cleanliness
#  count    42931.000000
# mean         3.227317
# std          2.484380
# min         -1.000000
# 25%          0.000000
# 50%          4.640000
# 75%          4.930000
# max          5.000000
# Name: review_scores_cleanliness, dtype: float64
#
# review_scores_checkin
#  count    42931.000000
# mean         3.358969
# std          2.544136
# min         -1.000000
# 25%         -1.000000
# 50%          4.860000
# 75%          5.000000
# max          5.000000
# Name: review_scores_checkin, dtype: float64
#
# review_scores_communication
#  count    42931.000000
# mean         3.359308
# std          2.545195
# min         -1.000000
# 25%         -1.000000
# 50%          4.880000
# 75%          5.000000
# max          5.000000
# Name: review_scores_communication, dtype: float64
#
# review_scores_location
#  count    42931.000000
# mean         3.297742
# std          2.509318
# min         -1.000000
# 25%         -1.000000
# 50%          4.720000
# 75%          4.990000
# max          5.000000
# Name: review_scores_location, dtype: float64
#
# review_scores_value
#  count    42931.000000
# mean         3.229605
# std          2.481870
# min         -1.000000
# 25%         -1.000000
# 50%          4.650000
# 75%          4.880000
# max          5.000000
# Name: review_scores_value, dtype: float64

# %%
#zapisz do pliku
df_listings.to_excel('dim_listings.xlsx', index=False,  engine='xlsxwriter')

# %% [markdown]
# ### Wymiar location

# %% [markdown]
# Ekstrakcja danych

# %%
df_locations = df[['neighbourhood_id','neighbourhood_cleansed', 'neighbourhood_group_cleansed']]
df_locations.head()
# Out:
#    neighbourhood_id neighbourhood_cleansed neighbourhood_group_cleansed
# 0                29               Canarsie                     Brooklyn
# 1                29               Canarsie                     Brooklyn
# 2               197            Tottenville                Staten Island
# 3               177         Sheepshead Bay                     Brooklyn
# 4               148        North Riverdale                        Bronx

# %% [markdown]
# Identyfikacja anomalii

# %%
#weryfikujemy czy dane posiadaja założoną wartość
for col in df_locations.columns:
    print(col, df_locations[col].unique())
# Out:
# neighbourhood_id [ 29 197 177 148  78 214 159 166 113  13 162  72  68  56 170  22  44 158
#  107  11  10 167 150 118 122 149  60  91  49  39 186 151 194   3  31   7
#  196  80 209 120 183 101  40 189 130  82 168  99 164  55  15 152 185 192
#   79 188 210 198  77 131 207 208 219  69  38   2  64 138  67  19 215 142
#    9 216   4 201 175 155 111 108 134 105 187 136 125 212 157 112 205  93
#    0  21 156  16  27 110   5 109 106 218 133  61  75  50  48  59 135  53
#  119 126 137 191  86 222  17  62  98 203  65  96 171  47  12 153 160  52
#   30 204 132 161  25 129  24  74  43  58 206  54  81 140  41 139  18  87
#  184 115  28   6 199  35 200 180  33 211 117  76  97 121  94  37  88 147
#  127 114  84  23 173 193 202 104 174  42 124 145 176  14 165  73  89 154
#  181 163 217  66 172 195 178 220 190  63  45 146 103   1  36  70 100  46
#  123 169  95  92 213  32  71 144  26  34  51   8 116 182  20  90  57 179
#   85 143 128  83 102 221 141]
# neighbourhood_cleansed ['Canarsie' 'Tottenville' 'Sheepshead Bay' 'North Riverdale' 'Flushing'
#  'Whitestone' "Prince's Bay" 'Richmond Hill' 'Kingsbridge' 'Belle Harbor'
#  'Queens Village' 'Far Rockaway' 'Edgemere' 'Dongan Hills'
#  'Rockaway Beach' 'Brighton Beach' 'College Point' 'Port Richmond'
#  'Jamaica' 'Bayswater' 'Bayside' 'Richmondtown' 'Oakwood' 'Little Neck'
#  'Manhattan Beach' 'Norwood' 'East Elmhurst' 'Gravesend' 'Coney Island'
#  'Clason Point' 'Spuyten Duyvil' 'Olinville' 'Throgs Neck' 'Arverne'
#  'Castle Hill' 'Bay Ridge' 'Tompkinsville' 'Forest Hills' 'West Brighton'
#  'Longwood' 'South Ozone Park' 'Howard Beach' 'Clifton' 'Stapleton'
#  'Midwood' 'Fort Hamilton' 'Ridgewood' 'Hollis' 'Red Hook'
#  'Ditmars Steinway' 'Belmont' 'Ozone Park' 'Springfield Gardens'
#  'Sunset Park' 'Fordham' 'St. George' 'West Farms' 'Tremont' 'Flatlands'
#  'Mill Basin' 'Wakefield' 'Washington Heights' 'Woodhaven' 'Elmhurst'
#  'Claremont Village' 'Arrochar' 'East New York' 'Mount Hope' 'Edenwald'
#  'Borough Park' 'Williamsbridge' 'New Brighton' 'Baychester'
#  'Williamsburg' 'Astoria' 'Unionport' 'Schuylerville' 'Pelham Bay'
#  'Kew Gardens' 'Jamaica Estates' 'Morris Park' 'Inwood' 'St. Albans'
#  'Mott Haven' 'Maspeth' 'Westchester Square' 'Port Morris'
#  'Kew Gardens Hills' 'Van Nest' 'Greenpoint' 'Allerton' 'Briarwood'
#  'Pelham Gardens' 'Bensonhurst' 'Bushwick' 'Kensington' 'Bath Beach'
#  'Jamaica Hills' 'Jackson Heights' 'Windsor Terrace' 'Morris Heights'
#  'East Flatbush' 'Flatbush' 'Corona' 'Concourse Village' 'Dyker Heights'
#  'Morrisania' 'Cypress Hills' 'Long Island City' 'Melrose' 'Mount Eden'
#  'Sunnyside' 'Glendale' 'Woodside' 'Bergen Beach' 'East Harlem'
#  'Highbridge' 'Upper East Side' 'East Village' 'Harlem' 'Roosevelt Island'
#  'Concourse' 'Bedford-Stuyvesant' 'Park Slope' 'Prospect Heights'
#  'Crown Heights' 'Carroll Gardens' 'Upper West Side' 'Morningside Heights'
#  'Prospect-Lefferts Gardens' 'Brownsville' 'Midtown' 'Brooklyn Heights'
#  'Financial District' 'Cobble Hill' 'Downtown Brooklyn' 'Vinegar Hill'
#  'DUMBO' 'Fort Greene' 'Navy Yard' 'Clinton Hill' 'Murray Hill'
#  'Boerum Hill' 'Gowanus' 'South Slope' 'Laurelton' 'Cambria Heights'
#  'Battery Park City' 'Tribeca' 'Chinatown' 'Two Bridges' 'SoHo' 'Chelsea'
#  'West Village' 'Little Italy' 'Flatiron District' "Hell's Kitchen"
#  'Lower East Side' 'Greenwich Village' 'Civic Center' 'Gramercy' 'Nolita'
#  'Middle Village' 'Kips Bay' 'Fresh Meadows' 'Bronxdale' 'Rosedale'
#  'Theater District' 'University Heights' 'Hunts Point' 'Rossville'
#  'Co-op City' 'Mariners Harbor' 'New Springville' 'Sea Gate' 'Bellerose'
#  'Rego Park' 'Fieldston' 'Graniteville' 'Parkchester' 'Soundview'
#  'Randall Manor' 'Willowbrook' 'Eastchester' 'Rosebank' 'Todt Hill'
#  'Shore Acres' 'Woodlawn' 'Stuyvesant Town' 'East Morrisania'
#  'Columbia St' 'NoHo' 'Huguenot' 'Arden Heights' 'City Island'
#  'Eltingville' 'Holliswood' 'Concord' 'Marble Hill' 'Riverdale'
#  'Grymes Hill' 'Great Kills' 'Westerleigh' 'Castleton Corners'
#  'Emerson Hill' 'New Dorp Beach' "Bull's Head" 'Chelsea, Staten Island'
#  'Country Club' 'Bay Terrace' 'Lighthouse Hill' 'South Beach'
#  'Breezy Point' 'Grant City' 'Douglaston' 'Silver Lake' 'Gerritsen Beach'
#  'New Dorp' 'Midland Beach' 'Fort Wadsworth' 'Howland Hook' 'Woodrow'
#  'Neponsit']
# neighbourhood_group_cleansed ['Brooklyn' 'Staten Island' 'Bronx' 'Queens' 'Manhattan']

# %%
#sprawdzamy puste wartości
df_locations.isnull().sum()
# Out:
# neighbourhood_id                0
# neighbourhood_cleansed          0
# neighbourhood_group_cleansed    0
# dtype: int64

# %%
#sprawdzamy duplikaty
df_locations.duplicated().sum()
# Out:
# 42708

# %%
#data types
df_locations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42931 entries, 0 to 42930
# Data columns (total 3 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   neighbourhood_id              42931 non-null  int16
#  1   neighbourhood_cleansed        42931 non-null  object
#  2   neighbourhood_group_cleansed  42931 non-null  object
# dtypes: int16(1), object(2)
# memory usage: 754.8+ KB

# %% [markdown]
# Transformacja danych

# %%
df_locations = df_locations.drop_duplicates()
df_locations.duplicated().sum()
# Out:
# 0

# %%
#reneame the columns
df_locations = df_locations.rename(columns={'neighbourhood_cleansed': 'neighbourhood', 'neighbourhood_group_cleansed': 'neighbourhood_group'})
#sort by neighbourhood_id
df_locations = df_locations.sort_values(by=['neighbourhood_id'])

df_locations.head()
# Out:
#       neighbourhood_id  neighbourhood neighbourhood_group
# 266                  0       Allerton               Bronx
# 5345                 1  Arden Heights       Staten Island
# 168                  2       Arrochar       Staten Island
# 73                   3        Arverne              Queens
# 187                  4        Astoria              Queens

# %%
#zmiana typu danych
text_columns = ['neighbourhood', 'neighbourhood_group']

for col in text_columns:
    df_locations = change_type_to_str(df_locations, col)

df_locations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 223 entries, 266 to 577
# Data columns (total 3 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   neighbourhood_id     223 non-null    int16
#  1   neighbourhood        223 non-null    string
#  2   neighbourhood_group  223 non-null    string
# dtypes: int16(1), string(2)
# memory usage: 5.7 KB

# %%
#save the cleaned data
df_locations.to_excel('dim_locations.xlsx', index=False)

# %% [markdown]
# ### Wymiar location details

# %% [markdown]
# Ekstrakcja danych

# %%
df_location_details = df[['location_id','latitude','longitude']]
df_location_details.head()
# Out:
#    location_id            latitude           longitude
# 0         2125  40.640402656712844  -73.88853475272201
# 1         2859            40.64851           -73.89433
# 2            2           40.507114          -74.251907
# 3          227            40.58349           -73.95988
# 4        41779            40.90326           -73.90709

# %% [markdown]
# Identyfikacja anomalii

# %%
for col in df_location_details.columns:
    print(col, df_location_details[col].unique())
# Out:
# location_id [ 2125  2859     2 ... 18949 10540 25349]
# latitude ['40.640402656712844' '40.64851' '40.507114' ... '40.76318689388868'
#  '40.76215' '40.68735']
# longitude ['-73.88853475272201' '-73.89433' '-74.251907' ... '-73.98979'
#  '-73.98517865966154' '-73.99247229211693']

# %%
#sprawdzamy duplikaty
df_location_details.duplicated().sum()
# Out:
# 1138

# %%
#sprawdzamy puste wartości
df_location_details.isnull().sum()
# Out:
# location_id    0
# latitude       0
# longitude      0
# dtype: int64

# %%
#sprawdzamy statystyki
df_location_details.describe()
# Out:
#         location_id
# count  42931.000000
# mean   21006.291701
# std    12023.475623
# min        0.000000
# 25%    10607.500000
# 50%    21136.000000
# 75%    31336.500000
# max    41792.000000

# %%
#sprawdzamy typy danych
df_location_details.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42931 entries, 0 to 42930
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   location_id  42931 non-null  int32
#  1   latitude     42931 non-null  object
#  2   longitude    42931 non-null  object
# dtypes: int32(1), object(2)
# memory usage: 838.6+ KB

# %% [markdown]
# Transformacja danych

# %%
#usuwamy duplikaty
df_location_details = df_location_details.drop_duplicates()
df_location_details.duplicated().sum()
# Out:
# 0

# %%
#zmieniamy typ danych
df_location_details['location_id'] = df_location_details['location_id'].astype('int64')
df_location_details['latitude'] = df_location_details['latitude'].astype('float64')
df_location_details['longitude'] = df_location_details['longitude'].astype('float64')
df_location_details.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41793 entries, 0 to 42930
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   location_id  41793 non-null  int64
#  1   latitude     41793 non-null  float64
#  2   longitude    41793 non-null  float64
# dtypes: float64(2), int64(1)
# memory usage: 1.3 MB

# %%
float_columns = ['latitude', 'longitude']
for col in float_columns:
    print(col,"\n", print_stats(df_location_details, df_location_details[col]), "\n")
# Out:
# latitude
#  count    41793.000000
# mean        40.727910
# std          0.057938
# min         40.500314
# 25%         40.687130
# 50%         40.723020
# 75%         40.762300
# max         40.911380
# Name: latitude, dtype: float64
#
# longitude
#  count    41793.000000
# mean       -73.943276
# std          0.056585
# min        -74.251907
# 25%        -73.981320
# 50%        -73.952110
# 75%        -73.923670
# max        -73.710870
# Name: longitude, dtype: float64

# %%
#zapisujemy dane do pliku
df_location_details.to_excel('dim_location_details.xlsx', index=False)

# %% [markdown]
# ### Wymiar Host

# %% [markdown]
# Ekstrakcja danych

# %%
df_host = df[['host_id','host_url', 'host_name', 'host_since', 'host_location', 'host_response_time', 'host_is_superhost', 'host_total_listings_count', 'host_identity_verified']]

df_host.head()
# Out:
#      host_id                                     host_url  host_name  \
# 0  495455523  https://www.airbnb.com/users/show/495455523    Michael
# 1  488760226  https://www.airbnb.com/users/show/488760226       Eric
# 2  461263600  https://www.airbnb.com/users/show/461263600    Tommaso
# 3  475699129  https://www.airbnb.com/users/show/475699129    Suliman
# 4  397288055  https://www.airbnb.com/users/show/397288055  Katherine
#
#    host_since host_location host_response_time host_is_superhost  \
# 0  2023-01-10           NaN                NaN                 f
# 1  2022-11-22           NaN     within an hour                 f
# 2  2022-05-27           NaN                NaN                 f
# 3  2022-08-18           NaN     within an hour                 t
# 4  2021-04-16           NaN     within an hour                 f
#
#   host_total_listings_count host_identity_verified
# 0                         1                      f
# 1                         5                      t
# 2                         1                      f
# 3                         7                      t
# 4                         2                      t

# %%
for col in df_host.columns:
    print(col, df_host[col].unique())
# Out:
# host_id ['495455523' '488760226' '461263600' ... '726333' '264962468' '6600525']
# host_url ['https://www.airbnb.com/users/show/495455523'
#  'https://www.airbnb.com/users/show/488760226'
#  'https://www.airbnb.com/users/show/461263600' ...
#  'https://www.airbnb.com/users/show/726333'
#  'https://www.airbnb.com/users/show/264962468'
#  'https://www.airbnb.com/users/show/6600525']
# host_name ['Michael' 'Eric' 'Tommaso' ... 'Davina' 'Etiam' 'Scotty']
# host_since ['2023-01-10' '2022-11-22' '2022-05-27' ... '2010-07-21' '2011-02-02'
#  '2010-06-24']
# host_location [nan 'New York, NY' 'United States' ... 'East Patchogue, NY' 'Bailey, CO'
#  'Heredia, Costa Rica']
# host_response_time [nan 'within an hour' 'a few days or more' 'within a few hours'
#  'within a day']
# host_is_superhost ['f' 't' nan]
# host_total_listings_count ['1' '5' '7' '2' '20' '3' '21' '6' '9' '13' '10' '4' '8' '15' '562' '14'
#  '16' '17' '28' '12' '283' '19' '34' '52' '246' '231' '11' '327' '2018'
#  '58' '68' '23' '18' '94' '43' '342' '40' '127' '747' '29' '5310' '24'
#  '22' '151' '90' '44' '82' '2268' '106' '240' '220' '979' '66' '71' '31'
#  '27' '80' '86' '25' '239' '37' '110' '49' '39' '46' '143' '51' '26' '306'
#  '352' '269' '8298' '54' '229' '57' '840' '30' '32' '375' '244' '167'
#  '841' '520' '105' '109' '364' '270' '36' '7769' '163' '1745' '38' '77'
#  '42' '35' '41' '1962' '114' '138' '56' '59' '72' '50' '299' '107' nan
#  '89' '346' '48' '2750' '88' '570' '74' '179' '115' '118' '150' '4522'
#  '415' '81' '642' '45' '298' '158' '736' '47' '491' '257' '435' '64' '33'
#  '249' '156' '238' '1105' '79' '91' '838' '224' '204' '288' '177' '252'
#  '707' '73' '3035' '303' '662']
# host_identity_verified ['f' 't' nan]

# %%
#check duplicates of host_id
df_host.duplicated(subset=['host_id']).sum()
# Out:
# 15476

# %%
#check for missing values
df_host.isnull().sum()
# Out:
# host_id                          0
# host_url                         0
# host_name                        5
# host_since                       5
# host_location                 9086
# host_response_time           14532
# host_is_superhost               25
# host_total_listings_count        5
# host_identity_verified           5
# dtype: int64

# %%
#typy danych
df_host.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42931 entries, 0 to 42930
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   host_id                    42931 non-null  object
#  1   host_url                   42931 non-null  object
#  2   host_name                  42926 non-null  object
#  3   host_since                 42926 non-null  object
#  4   host_location              33845 non-null  object
#  5   host_response_time         28399 non-null  object
#  6   host_is_superhost          42906 non-null  object
#  7   host_total_listings_count  42926 non-null  object
#  8   host_identity_verified     42926 non-null  object
# dtypes: object(9)
# memory usage: 2.9+ MB

# %% [markdown]
# Transformacja danych

# %%
#delete duplicates
df_host.drop_duplicates(subset=['host_id'], inplace=True)
df_host.duplicated(subset=['host_id']).sum()
# Out:
# C:\Users\dabro\AppData\Local\Temp\ipykernel_4328\2329217901.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_host.drop_duplicates(subset=['host_id'], inplace=True)
# 0

# %%
#handling missing values
df_host['host_name'] = df_host['host_name'].fillna('unknown')
df_host['host_location'] = df_host['host_location'].fillna('unknown')
df_host['host_response_time'] = df_host['host_response_time'].fillna('unknown')
df_host['host_total_listings_count'] = df_host['host_total_listings_count'].fillna(-1)

df_host.isnull().sum()
# Out:
# C:\Users\dabro\AppData\Local\Temp\ipykernel_4328\3368295849.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_host['host_name'] = df_host['host_name'].fillna('unknown')
# C:\Users\dabro\AppData\Local\Temp\ipykernel_4328\3368295849.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_host['host_location'] = df_host['host_location'].fillna('unknown')
# C:\Users\dabro\AppData\Local\Temp\ipykernel_4328\3368295849.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_host['host_response_time'] = df_host['host_response_time'].fillna('unknown')
# C:\Users\dabro\AppData\Local\Temp\ipykernel_4328\3368295849.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_host['host_total_listings_count'] = df_host['host_total_listings_count'].fillna(-1)
# host_id                       0
# host_url                      0
# host_name                     0
# host_since                    5
# host_location                 0
# host_response_time            0
# host_is_superhost            25
# host_total_listings_count     0
# host_identity_verified        5
# dtype: int64

# %%
#zmiana typu danych
text_columns = ['host_url', 'host_name', 'host_location', 'host_response_time']
int_columns = ['host_id', 'host_total_listings_count']

for col in int_columns:
    df_host = change_type_to_int(df_host, col)
    
for col in text_columns:
    df_host = change_type_to_str(df_host, col)

#zmiana typu danych na bool
df_host['host_is_superhost'] = df_host['host_is_superhost'].replace({'t': True, 'f': False})
df_host['host_identity_verified'] = df_host['host_identity_verified'].replace({'t': True, 'f': False})
df_host['host_is_superhost'] = df_host['host_is_superhost'].astype('bool')
df_host['host_identity_verified'] = df_host['host_identity_verified'].astype('bool')

#zmiana typu danych host_since
df_host['host_since'] = pd.to_datetime(df_host['host_since'])

df_host.info()
# Out:
# C:\Users\dabro\AppData\Local\Temp\ipykernel_4328\4152442605.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].astype('int64')
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27455 entries, 0 to 42929
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   host_id                    27455 non-null  int64
#  1   host_url                   27455 non-null  string
#  2   host_name                  27455 non-null  string
#  3   host_since                 27450 non-null  datetime64[ns]
#  4   host_location              27455 non-null  string
#  5   host_response_time         27455 non-null  string
#  6   host_is_superhost          27455 non-null  bool
#  7   host_total_listings_count  27455 non-null  int64
#  8   host_identity_verified     27455 non-null  bool
# dtypes: bool(2), datetime64[ns](1), int64(2), string(4)
# memory usage: 1.7 MB
# C:\Users\dabro\AppData\Local\Temp\ipykernel_4328\4152442605.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].astype(pd.StringDtype())
# C:\Users\dabro\AppData\Local\Temp\ipykernel_4328\705256887.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_host['host_is_superhost'] = df_host['host_is_superhost'].replace({'t': True, 'f': False})
# C:\Users\dabro\AppData\Local\Temp\ipykernel_4328\705256887.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_host['host_identity_verified'] = df_host['host_identity_verified'].replace({'t': True, 'f': False})
# C:\Users\dabro\AppData\Local\Temp\ipykernel_4328\705256887.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_host['host_is_superhost'] = df_host['host_is_superhost'].astype('bool')
# C:\Users\dabro\AppData\Local\Temp\ipykernel_4328\705256887.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_host['host_since'] = pd.to_datetime(df_host['host_since'])

# %%
float_columns = ['host_total_listings_count']
for col in float_columns:
    print(col,"\n", print_stats(df_host, df_host[col]), "\n")
# Out:
# host_total_listings_count
#  count    27455.000000
# mean         4.972282
# std         89.898471
# min         -1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max       8298.000000
# Name: host_total_listings_count, dtype: float64

# %%
#zapisanie danych do pliku
df_host.to_excel('dim_host.xlsx', index=False)

# %% [markdown]
# ###  Tabela faktów- wynajem

# %% [markdown]
# Określenie trybu dostępu do danych:
#
# Pobrane ze strony dane mają postać plików CSV skompresowanych do pliku o rozszerzeniu .gz. Dla tabeli faktów jest to plik **calendar.csv.gz.**
# Tryb dostępu: Otwieranie i odczytywanie pliku CSV przy użyciu biblioteki pandas metodą read_csv, z dodatkowym argumentem dekompresji jako gzip

# %% [markdown]
# Ekstrakcja danych

# %%
#wczytujemy dane
df_rents = pd.read_csv('calendar.csv.gz', compression='gzip', usecols=['listing_id', 'date', 'available', 'price'])

df_rents.head()
# Out:
#    listing_id        date available    price
# 0        2595  2023-03-07         t  $150.00
# 1        2595  2023-03-08         t  $150.00
# 2        2595  2023-03-09         t  $150.00
# 3        2595  2023-03-10         f  $150.00
# 4        2595  2023-03-11         f  $150.00

# %%
for col in df_rents.columns:
    print(col, df_rents[col].unique())
# Out:
# listing_id [              2595               5121               5136 ...
#  840150322371056021 840228878772481467 840466047136140141]
# date ['2023-03-07' '2023-03-08' '2023-03-09' '2023-03-10' '2023-03-11'
#  '2023-03-12' '2023-03-13' '2023-03-14' '2023-03-15' '2023-03-16'
#  '2023-03-17' '2023-03-18' '2023-03-19' '2023-03-20' '2023-03-21'
#  '2023-03-22' '2023-03-23' '2023-03-24' '2023-03-25' '2023-03-26'
#  '2023-03-27' '2023-03-28' '2023-03-29' '2023-03-30' '2023-03-31'
#  '2023-04-01' '2023-04-02' '2023-04-03' '2023-04-04' '2023-04-05'
#  '2023-04-06' '2023-04-07' '2023-04-08' '2023-04-09' '2023-04-10'
#  '2023-04-11' '2023-04-12' '2023-04-13' '2023-04-14' '2023-04-15'
#  '2023-04-16' '2023-04-17' '2023-04-18' '2023-04-19' '2023-04-20'
#  '2023-04-21' '2023-04-22' '2023-04-23' '2023-04-24' '2023-04-25'
#  '2023-04-26' '2023-04-27' '2023-04-28' '2023-04-29' '2023-04-30'
#  '2023-05-01' '2023-05-02' '2023-05-03' '2023-05-04' '2023-05-05'
#  '2023-05-06' '2023-05-07' '2023-05-08' '2023-05-09' '2023-05-10'
#  '2023-05-11' '2023-05-12' '2023-05-13' '2023-05-14' '2023-05-15'
#  '2023-05-16' '2023-05-17' '2023-05-18' '2023-05-19' '2023-05-20'
#  '2023-05-21' '2023-05-22' '2023-05-23' '2023-05-24' '2023-05-25'
#  '2023-05-26' '2023-05-27' '2023-05-28' '2023-05-29' '2023-05-30'
#  '2023-05-31' '2023-06-01' '2023-06-02' '2023-06-03' '2023-06-04'
#  '2023-06-05' '2023-06-06' '2023-06-07' '2023-06-08' '2023-06-09'
#  '2023-06-10' '2023-06-11' '2023-06-12' '2023-06-13' '2023-06-14'
#  '2023-06-15' '2023-06-16' '2023-06-17' '2023-06-18' '2023-06-19'
#  '2023-06-20' '2023-06-21' '2023-06-22' '2023-06-23' '2023-06-24'
#  '2023-06-25' '2023-06-26' '2023-06-27' '2023-06-28' '2023-06-29'
#  '2023-06-30' '2023-07-01' '2023-07-02' '2023-07-03' '2023-07-04'
#  '2023-07-05' '2023-07-06' '2023-07-07' '2023-07-08' '2023-07-09'
#  '2023-07-10' '2023-07-11' '2023-07-12' '2023-07-13' '2023-07-14'
#  '2023-07-15' '2023-07-16' '2023-07-17' '2023-07-18' '2023-07-19'
#  '2023-07-20' '2023-07-21' '2023-07-22' '2023-07-23' '2023-07-24'
#  '2023-07-25' '2023-07-26' '2023-07-27' '2023-07-28' '2023-07-29'
#  '2023-07-30' '2023-07-31' '2023-08-01' '2023-08-02' '2023-08-03'
#  '2023-08-04' '2023-08-05' '2023-08-06' '2023-08-07' '2023-08-08'
#  '2023-08-09' '2023-08-10' '2023-08-11' '2023-08-12' '2023-08-13'
#  '2023-08-14' '2023-08-15' '2023-08-16' '2023-08-17' '2023-08-18'
#  '2023-08-19' '2023-08-20' '2023-08-21' '2023-08-22' '2023-08-23'
#  '2023-08-24' '2023-08-25' '2023-08-26' '2023-08-27' '2023-08-28'
#  '2023-08-29' '2023-08-30' '2023-08-31' '2023-09-01' '2023-09-02'
#  '2023-09-03' '2023-09-04' '2023-09-05' '2023-09-06' '2023-09-07'
#  '2023-09-08' '2023-09-09' '2023-09-10' '2023-09-11' '2023-09-12'
#  '2023-09-13' '2023-09-14' '2023-09-15' '2023-09-16' '2023-09-17'
#  '2023-09-18' '2023-09-19' '2023-09-20' '2023-09-21' '2023-09-22'
#  '2023-09-23' '2023-09-24' '2023-09-25' '2023-09-26' '2023-09-27'
#  '2023-09-28' '2023-09-29' '2023-09-30' '2023-10-01' '2023-10-02'
#  '2023-10-03' '2023-10-04' '2023-10-05' '2023-10-06' '2023-10-07'
#  '2023-10-08' '2023-10-09' '2023-10-10' '2023-10-11' '2023-10-12'
#  '2023-10-13' '2023-10-14' '2023-10-15' '2023-10-16' '2023-10-17'
#  '2023-10-18' '2023-10-19' '2023-10-20' '2023-10-21' '2023-10-22'
#  '2023-10-23' '2023-10-24' '2023-10-25' '2023-10-26' '2023-10-27'
#  '2023-10-28' '2023-10-29' '2023-10-30' '2023-10-31' '2023-11-01'
#  '2023-11-02' '2023-11-03' '2023-11-04' '2023-11-05' '2023-11-06'
#  '2023-11-07' '2023-11-08' '2023-11-09' '2023-11-10' '2023-11-11'
#  '2023-11-12' '2023-11-13' '2023-11-14' '2023-11-15' '2023-11-16'
#  '2023-11-17' '2023-11-18' '2023-11-19' '2023-11-20' '2023-11-21'
#  '2023-11-22' '2023-11-23' '2023-11-24' '2023-11-25' '2023-11-26'
#  '2023-11-27' '2023-11-28' '2023-11-29' '2023-11-30' '2023-12-01'
#  '2023-12-02' '2023-12-03' '2023-12-04' '2023-12-05' '2023-12-06'
#  '2023-12-07' '2023-12-08' '2023-12-09' '2023-12-10' '2023-12-11'
#  '2023-12-12' '2023-12-13' '2023-12-14' '2023-12-15' '2023-12-16'
#  '2023-12-17' '2023-12-18' '2023-12-19' '2023-12-20' '2023-12-21'
#  '2023-12-22' '2023-12-23' '2023-12-24' '2023-12-25' '2023-12-26'
#  '2023-12-27' '2023-12-28' '2023-12-29' '2023-12-30' '2023-12-31'
#  '2024-01-01' '2024-01-02' '2024-01-03' '2024-01-04' '2024-01-05'
#  '2024-01-06' '2024-01-07' '2024-01-08' '2024-01-09' '2024-01-10'
#  '2024-01-11' '2024-01-12' '2024-01-13' '2024-01-14' '2024-01-15'
#  '2024-01-16' '2024-01-17' '2024-01-18' '2024-01-19' '2024-01-20'
#  '2024-01-21' '2024-01-22' '2024-01-23' '2024-01-24' '2024-01-25'
#  '2024-01-26' '2024-01-27' '2024-01-28' '2024-01-29' '2024-01-30'
#  '2024-01-31' '2024-02-01' '2024-02-02' '2024-02-03' '2024-02-04'
#  '2024-02-05' '2024-02-06' '2024-02-07' '2024-02-08' '2024-02-09'
#  '2024-02-10' '2024-02-11' '2024-02-12' '2024-02-13' '2024-02-14'
#  '2024-02-15' '2024-02-16' '2024-02-17' '2024-02-18' '2024-02-19'
#  '2024-02-20' '2024-02-21' '2024-02-22' '2024-02-23' '2024-02-24'
#  '2024-02-25' '2024-02-26' '2024-02-27' '2024-02-28' '2024-02-29'
#  '2024-03-01' '2024-03-02' '2024-03-03' '2024-03-04' '2024-03-05'
#  '2023-03-06']
# available ['t' 'f']
# price ['$150.00' '$164.00' '$191.00' ... '$2,628.00' '$2,413.00' '$2,971.00']

# %%
df_rents.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15664741 entries, 0 to 15664740
# Data columns (total 4 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   listing_id  int64
#  1   date        object
#  2   available   object
#  3   price       object
# dtypes: int64(1), object(3)
# memory usage: 478.1+ MB

# %%
df_rents.isnull().sum()
# Out:
# listing_id       0
# date             0
# available        0
# price         1112
# dtype: int64

# %%
df_rents.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Transformacja danych

# %%
#obsluga brakujacych danych
df_rents['price'] = df_rents['price'].fillna(-1)
df_rents.isnull().sum()
# Out:
# listing_id    0
# date          0
# available     0
# price         0
# dtype: int64

# %%
#zmiana typu danych
df_rents['date'] = pd.to_datetime(df_rents['date'])
df_rents['price'] = df_rents['price'].str.replace('$', '').str.replace(',', '').astype(float)
df_rents['available'] = df_rents['available'].map({'t': True, 'f': False})
df_rents['available'] = df_rents['available'].astype('bool')
df_rents.info()
# Out:
# C:\Users\dabro\AppData\Local\Temp\ipykernel_4328\549253080.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_rents['price'] = df_rents['price'].str.replace('$', '').str.replace(',', '').astype(float)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15664741 entries, 0 to 15664740
# Data columns (total 4 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   listing_id  int64
#  1   date        datetime64[ns]
#  2   available   bool
#  3   price       float64
# dtypes: bool(1), datetime64[ns](1), float64(1), int64(1)
# memory usage: 373.5 MB

# %%
float_columns = ['price']
for col in float_columns:
    print(col,"\n", print_stats(df_rents, df_rents[col]), "\n")
# Out:
# price
#  count    1.566363e+07
# mean     2.191347e+02
# std      7.523764e+02
# min      0.000000e+00
# 25%      8.000000e+01
# 50%      1.350000e+02
# 75%      2.250000e+02
# max      1.000000e+05
# Name: price, dtype: float64

# %%
df_rents
# Out:
#                   listing_id       date  available  price
# 0                       2595 2023-03-07       True  150.0
# 1                       2595 2023-03-08       True  150.0
# 2                       2595 2023-03-09       True  150.0
# 3                       2595 2023-03-10      False  150.0
# 4                       2595 2023-03-11      False  150.0
# ...                      ...        ...        ...    ...
# 15664736  840466047136140141 2024-03-01      False  100.0
# 15664737  840466047136140141 2024-03-02      False  100.0
# 15664738  840466047136140141 2024-03-03      False  100.0
# 15664739  840466047136140141 2024-03-04      False  100.0
# 15664740  840466047136140141 2024-03-05      False  100.0
#
# [15664741 rows x 4 columns]

# %%
#merge data from df_rents and df to get location_id, listing_id, host_id, neighbourhood_id where  listing_id = id
df['id'] = df['id'].astype('int64')
df_rents = pd.merge(df_rents, df[['id','location_id',  'host_id', 'neighbourhood_id']], left_on='listing_id', right_on='id', how='left')
df_rents = df_rents.drop(columns=['id'])
df_rents.head()
# Out:
#    listing_id       date  available  price  location_id host_id  \
# 0        2595 2023-03-07       True  150.0        28702    2845
# 1        2595 2023-03-08       True  150.0        28702    2845
# 2        2595 2023-03-09       True  150.0        28702    2845
# 3        2595 2023-03-10      False  150.0        28702    2845
# 4        2595 2023-03-11      False  150.0        28702    2845
#
#    neighbourhood_id
# 0               129
# 1               129
# 2               129
# 3               129
# 4               129

# %%
df_rents['host_id'] = df_rents['host_id'].astype('int64')
df_rents.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15664741 entries, 0 to 15664740
# Data columns (total 7 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   listing_id        int64
#  1   date              datetime64[ns]
#  2   available         bool
#  3   price             float64
#  4   location_id       int32
#  5   host_id           int64
#  6   neighbourhood_id  int16
# dtypes: bool(1), datetime64[ns](1), float64(1), int16(1), int32(1), int64(2)
# memory usage: 702.1 MB

# %%
#save the cleaned data
df_rents.to_csv('fact_rents.csv', index=False)

# %% [markdown]
# ### Wymiar Availability

# %% [markdown]
# Określenie trybu dostępu do danych:
#
# Manualnie stworzony wymiar na potrzeby modelu wymiarowego.

# %%
#stworzenie dwukolumnowej tabeli
availability = {'availability': ['available', 'not available'], 'available': [True, False]}
df_available = pd.DataFrame(availability)

#zmiana typu danych
df_available['availability'] = df_available['availability'].astype(pd.StringDtype())
df_available['available'] = df_available['available'].astype('bool')
df_available.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   availability  2 non-null      string
#  1   available     2 non-null      bool
# dtypes: bool(1), string(1)
# memory usage: 146.0 bytes

# %%
#save the cleaned data
df_available.to_excel('dim_availability.xlsx', index=False)
